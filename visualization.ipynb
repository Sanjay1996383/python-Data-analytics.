# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.barplot(data= df ,x='species', y='sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
fig, ax = plt.subplots(figsize=(4,2))
sns.barplot(data =df, x='species', y='sepal_width',ax=ax)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
# create a 4 x 1 grid of subplots
fig, ax = plt.subplots(figsize=(20, 4), ncols=4)
sns.barplot(data=df, x='species', y='sepal_length', ax=ax[0])
sns.barplot(data=df, x='species', y='sepal_width', ax=ax[1])
sns.barplot(data=df, x='species', y='petal_length', ax=ax[2])
sns.barplot(data=df, x='species', y='petal_width', ax=ax[3])
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
# create a 2 x 2 grid of subplots
fig, ax = plt.subplots(figsize = (5,5) ,ncols=2, nrows=2)
sns.barplot(data=df, x ='species',y = 'sepal_length', ax=ax[0,0])
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>
