# %%
from  dputils.scrape import Scraper,Tag

# %%
url = 'https://www.flipkart.com/search?q=bages&otracker=AS_Query_HistoryAutoSuggest_2_0&otracker1=AS_Query_HistoryAutoSuggest_2_0&marketplace=FLIPKART&as-show=on&as=off&as-pos=2&as-type=HISTORY'
sc = Scraper(url)

# %%
target = Tag('div', cls = '_1YokD2 _3Mn1Gg') # important
items = Tag('div', cls = '_1xHGtK _373qXS') # important repeating item
brand = Tag('div', cls = '_2WkVRV')
details = Tag('a', cls='IRpwTa')
price = Tag('div', cls='_30jeq3')
color = Tag('div', cls='_3eWWd-')
discount = Tag('div', cls='_3Ay6Sb')

# %%
data = sc.get_all(
        target, items, brand=brand,
        details=details, price=price,
        color=color, discount=discount
)
print(len(data))
# Out:
# 40

# %%
data
# Out:
# [{'brand': 'Gear',
#   'details': 'Medium 27 L Backpack Bounce Backpack',
#   'price': '₹629',
#   'color': 'Grey, Orange',
#   'discount': '65% off'},
#  {'brand': 'Gear',
#   'details': 'Small 20 L Backpack Modern ECO 5 Backpack',
#   'price': '₹449',
#   'color': 'Blue',
#   'discount': '55% off'},
#  {'brand': 'PUMA',
#   'details': 'Medium 30 L Backpack One Spacious Unisex Multpurpose ba...',
#   'price': '₹799',
#   'color': 'Black',
#   'discount': '61% off'},
#  {'brand': 'WROGN',
#   'details': 'Medium 30 L Laptop Backpack Backpack For College School...',
#   'price': '₹389',
#   'color': 'Blue, Black',
#   'discount': '87% off'},
#  {'brand': 'PUMA',
#   'details': 'Medium 30 L Backpack One Spacious Unisex Multpurpose ba...',
#   'price': '₹849',
#   'color': 'Black',
#   'discount': '59% off'},
#  {'brand': 'WROGN',
#   'details': 'Medium 30 L Laptop Backpack Backpack For College School...',
#   'price': '₹389',
#   'color': 'Blue, Black',
#   'discount': '87% off'},
#  {'brand': 'PUMA',
#   'details': 'Large 34 L Backpack One Spacious Unisex Multpurpose bag...',
#   'price': '₹949',
#   'color': 'Blue',
#   'discount': '64% off'},
#  {'brand': 'WESTZONE',
#   'details': 'Small 20 L Backpack 20L backpack for school college off...',
#   'price': '₹369',
#   'color': 'Black',
#   'discount': '75% off'},
#  {'brand': 'sky spirit',
#   'details': 'Large 40 L Laptop Backpack Waterproof Large 40L Laptop ...',
#   'price': '₹338',
#   'color': 'Grey',
#   'discount': '83% off'},
#  {'brand': 'sky spirit',
#   'details': 'Large 40 L Laptop Backpack Waterproof Large 40L Laptop ...',
#   'price': '₹338',
#   'color': 'Green',
#   'discount': '83% off'},
#  {'brand': 'PUMA',
#   'details': 'Medium 30 L Backpack One Spacious Unisex Multpurpose ba...',
#   'price': '₹849',
#   'color': 'Yellow',
#   'discount': '59% off'},
#  {'brand': 'Gear',
#   'details': 'Medium 25 L Backpack BOMBER ECO STATEMENT 2C',
#   'price': '₹629',
#   'color': 'Blue, Black',
#   'discount': '68% off'},
#  {'brand': 'PUMA',
#   'details': 'Medium 30 L Backpack One Spacious Unisex Multpurpose ba...',
#   'price': '₹799',
#   'color': 'Blue',
#   'discount': '61% off'},
#  {'brand': 'PUMA',
#   'details': 'Large 34 L Backpack One Spacious Unisex Multpurpose bag...',
#   'price': '₹999',
#   'color': 'Black',
#   'discount': '62% off'},
#  {'brand': 'Roadster',
#   'details': 'Large 38 L Laptop Backpack Large Historage backpack Tra...',
#   'price': '₹554',
#   'color': 'Blue, Grey',
#   'discount': '72% off'},
#  {'brand': 'alfisha',
#   'details': 'Medium 30 L Laptop Backpack Casual unisex Bagpack schoo...',
#   'price': '₹441',
#   'color': 'Black',
#   'discount': '77% off'},
#  {'brand': 'PUMA',
#   'details': 'Medium 30 L Backpack One Spacious Unisex Multpurpose ba...',
#   'price': '₹849',
#   'color': 'Blue',
#   'discount': '59% off'},
#  {'brand': 'RIGHT CHOICE',
#   'details': 'Small 10 L Backpack college causal bag styish stuff qua...',
#   'price': '₹317',
#   'color': 'Grey',
#   'discount': '84% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Large 31 L Backpack RIDDLE',
#   'price': '₹1,279',
#   'color': 'Blue',
#   'discount': '50% off'},
#  {'brand': 'GOOD FRIENDS',
#   'details': 'Medium 21 L Backpack Design Premium Polyester Waterproo...',
#   'price': '₹381',
#   'color': 'Grey',
#   'discount': '72% off'},
#  {'brand': 'Roadster',
#   'details': 'Medium 23 L Laptop Backpack Medium Daypack',
#   'price': '₹415',
#   'color': 'Grey, Green',
#   'discount': '72% off'},
#  {'brand': 'WROGN',
#   'details': 'Large 35 L Laptop Backpack BP/REXINE/1500/BLACK-35L',
#   'price': '₹857',
#   'color': 'Black',
#   'discount': '82% off'},
#  {'brand': 'PROVOGUE',
#   'details': 'Small 12 L Backpack DAYPACK Drawstring Backpack Bag Dor...',
#   'price': '₹199',
#   'color': 'Multicolor',
#   'discount': '71% off'},
#  {'brand': 'zikrefast',
#   'details': 'Large 35 L Laptop Backpack Medium 35 L Backpack Premium...',
#   'price': '₹382',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'SKYBAGS',
#   'details': 'Medium 27 L Backpack Graf 27L',
#   'price': '₹1,039',
#   'color': 'Black',
#   'discount': '48% off'},
#  {'brand': 'aob',
#   'details': 'Large 70 L Backpack UNISEX WaterProof Mountain Rucksack...',
#   'price': '₹649',
#   'color': 'Grey',
#   'discount': '78% off'},
#  {'brand': 'sky spirit',
#   'details': 'Large 50 L Backpack Backpack large 50L for Outdoor Spor...',
#   'price': '₹495',
#   'color': 'Blue',
#   'discount': '80% off'},
#  {'brand': 'Justify',
#   'details': 'Large 70 L Backpack TRAVEL BACKPACK Hiking Bag Rucksack...',
#   'price': '₹824',
#   'color': 'Grey',
#   'discount': '79% off'},
#  {'brand': 'Roadster',
#   'details': 'Medium 23 L Laptop Backpack Medium Daypack',
#   'price': '₹415',
#   'color': 'Blue',
#   'discount': '72% off'},
#  {'brand': 'PLEXY',
#   'details': 'Medium 25 L Backpack SMALL 25 L DAYPACK BAGPACK FOR DAI...',
#   'price': '₹262',
#   'color': 'Black',
#   'discount': '82% off'},
#  {'brand': 'Lavie Sport',
#   'details': '33.957 L Backpack Hype 1 Backpack',
#   'price': '₹849',
#   'color': 'Blue',
#   'discount': '68% off'},
#  {'brand': 'Gear',
#   'details': 'Small 16 L Backpack SUPERIOR BACKPACK',
#   'price': '₹395',
#   'color': 'Orange, Black',
#   'discount': '56% off'},
#  {'brand': 'PROVOGUE',
#   'details': 'Large 45 L Laptop Backpack Unisex Bag with rain cover O...',
#   'price': '₹769',
#   'color': 'Multicolor',
#   'discount': '84% off'},
#  {'brand': 'PROVOGUE',
#   'details': 'Large 41 L Laptop Backpack Spacy Unisex Bag with rain c...',
#   'price': '₹776',
#   'color': 'Black',
#   'discount': '82% off'},
#  {'brand': 'WROGN',
#   'details': '55 L Laptop Backpack Laptop backpack spacy unisex backp...',
#   'price': '₹689',
#   'color': 'Blue',
#   'discount': '82% off'},
#  {'brand': 'LAYONEX',
#   'details': 'Medium 25 L Laptop Backpack Laptop Bag/ Laptop Backpack...',
#   'price': '₹490',
#   'color': 'Blue',
#   'discount': '67% off'},
#  {'brand': 'Pro Life',
#   'details': 'Small 20 L Backpack Poliyester School College Multipurp...',
#   'price': '₹380',
#   'color': 'Grey',
#   'discount': '78% off'},
#  {'brand': 'SKYBAGS',
#   'details': '21.65 L Backpack BRAT',
#   'price': '₹799',
#   'color': 'Black',
#   'discount': '61% off'},
#  {'brand': 'Flycraft',
#   'details': 'Large 35 L Laptop Backpack simna.1378 large 35 L airpor...',
#   'price': '₹594',
#   'color': 'Blue',
#   'discount': '80% off'},
#  {'brand': 'Gear',
#   'details': 'Small 18 L Backpack Eco 4 Navy Blue Green',
#   'price': '₹539',
#   'color': 'Green, Blue',
#   'discount': '50% off'}]
